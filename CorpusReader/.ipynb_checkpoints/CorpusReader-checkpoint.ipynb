# %%
import tarfile,os
import sys
import gzip
from xml.etree import ElementTree as ET

#os.chdir("/opt/nltk_data/nyt/data/1987")
#tar = tarfile.open("01.tgz")
#for member in [x for x in tar.getmembers()[:3] if str(x).find(".xml")>-1]:
#    print(member)
#    with tar.extractfile(member) as f:        
#        with f.readlines() as xml:
#            doc = ET.parse(xml).getroot()
#            print(doc.find('title').text)
#tar.close()

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

def plotFreqDistAsBarChart(fdist,n):
    words = [x[0] for x in fdist.most_common(n)]
    values = [x[1] for x in fdist.most_common(n)]
    matplotlib.style.use('ggplot')
    
    d = {'values': values}
    df = pd.DataFrame(d)


    ax = df.plot(kind='bar',legend=False,title='Word Frequencies for Most Common Words')
    ax.set_xticklabels(words)
    ax.set_xlabel("Words",fontsize=12)
    ax.set_ylabel("Occurrences",fontsize=12)

    plt.show()

# %%
from contextlib import closing
from xml.etree import ElementTree as etree

tags = []
tagsC = []

for i in range(6):
    with tarfile.open('/opt/nltk_data/nyt/data/2007/0'+str(i+1)+'.tgz') as archive:
        for member in archive:
            if member.isreg() and member.name.endswith('.xml'): # regular xml file
                with closing(archive.extractfile(member)) as xmlfile:
                    root = etree.parse(xmlfile).getroot()
                    for meta in root.findall(".//*[@name='online_sections']"):
                        newTags = meta.get("content").replace(" ","")
                        tagsC.extend([newTags]);
                        tags.extend(newTags.split(';'))

print(list(set(tags)))
print(len(list(set(tags))))

print(list(set(tagsC)))
print(len(list(set(tagsC))))


# Labels [9]: Arts, Business, Science, Sports, Technology, Health, Opinion, Washington (-> Politics), Style
# Label entfernen [11]: Magazine, Travel, HomeandGarden, Obituaries, World, DiningandWine, NewYorkandRegion, US, Education, FrontPage, RealEstate
# Datensatz entfernen [4]: PaidDeathNotices, WeekinReview, Corrections, JobMarket
# Mappen [6]: (Books, Theater, Movies -> Arts), (Automobile -> Business), (Editors' Notes, The Public Editor -> Opinion)
# Out:
# ['Education', 'RealEstate', 'FrontPage', 'Sports', 'U.S.', 'NewYorkandRegion', 'WeekinReview', 'Arts', 'Theater', 'ThePublicEditor', 'World', 'Technology', 'Style', 'Books', 'JobMarket', 'Business', 'Obituaries', 'Science', 'Corrections', 'Washington', 'Magazine', 'Travel', 'Movies', 'Opinion', 'DiningandWine', "Editors'Notes", 'Automobiles', 'PaidDeathNotices', 'HomeandGarden', 'Health']
# 30
# ['Technology;Business;Books;Opinion', 'Movies;Arts;Theater;Opinion', 'Health;Books', 'Education;Business;Books', 'FrontPage;Washington;NewYorkandRegion', 'Style;Books', 'Technology;FrontPage;Business;Washington', 'Technology;FrontPage;Education;U.S.', 'Movies;Arts;Health', 'Style', 'Science;World', 'Arts;Obituaries;Books', 'World;Health;Education', 'Science;Technology;Business;Books', 'Education;Corrections;Washington;NewYorkandRegion', 'Movies;Books;NewYorkandRegion', 'Technology;Magazine', 'Corrections', 'Travel;Style', 'Technology;Movies;Arts', 'Movies;Sports', 'World;FrontPage;Health;Education', 'Technology;Corrections;Books;NewYorkandRegion', 'Technology;Science;RealEstate', 'Movies;Magazine', 'Education;U.S.;Washington', 'FrontPage;Health;U.S.;Washington', 'Style;Washington', 'Technology;Arts;Books', 'Movies;Arts;Opinion', 'Arts;Style;Magazine', 'Technology;Travel;WeekinReview', 'Technology;Movies;Corrections;NewYorkandRegion', 'Travel;Arts;DiningandWine', "Corrections;Editors'Notes;Washington;NewYorkandRegion", 'Education;Corrections;WeekinReview', 'Education', 'World;Health;Theater', 'Technology;FrontPage;U.S.;Washington', 'Technology;Corrections;NewYorkandRegion', 'Travel;Arts;Theater', 'Technology;Science;Opinion', 'Technology;Education;Business', 'Style;Theater', 'Technology;RealEstate', 'Science;Arts;Washington', 'U.S.;Washington;Obituaries', 'Technology;Science;Travel', 'Health;Business', 'Movies;Obituaries;Sports', 'Movies;World', 'Arts;Theater;Obituaries', 'Technology;Science;Education;Opinion', 'Movies;Magazine;Opinion', 'Movies;Style;Opinion', 'RealEstate;Opinion', 'Science;Health;U.S.', 'Arts;Theater;Opinion', 'Technology;Science;Arts;Books', 'FrontPage;Health;U.S.', 'Business;Opinion', 'Arts;Washington;Books', 'Movies;Arts;Obituaries', 'Technology;NewYorkandRegion;Opinion', 'Travel;Theater', 'Technology;Movies;Style;Books', 'Obituaries;Books;NewYorkandRegion', 'Travel;Theater;NewYorkandRegion', 'Movies;Arts;Theater', 'Science;Technology;FrontPage;Business', 'Health;RealEstate', 'Science;Arts', 'Technology;Business;Washington;Books', 'U.S.;Washington', 'FrontPage;Business;Washington', 'FrontPage;Arts;Washington;Obituaries', 'Movies;U.S.;Books', "Arts;Corrections;Editors'Notes;Books", 'Technology;Movies;Arts;Washington', 'Technology;Arts;Theater', 'Technology;Health;NewYorkandRegion', 'Arts;DiningandWine', 'Education;Magazine;Opinion', 'Magazine', 'Travel', 'Movies;Education;NewYorkandRegion;Opinion', 'Movies;Arts;Education', 'Arts;DiningandWine;Books', 'Technology;Arts;Corrections', 'Education;Magazine;Books', 'Technology;Arts', 'Technology;Books;WeekinReview', 'Technology;Science;U.S.', 'Technology;Science;Education;Obituaries;NewYorkandRegion', 'Movies;Health;Education;NewYorkandRegion', 'HomeandGarden;Health;Style;Books', 'World;Theater', 'Technology;FrontPage;Health;Education;U.S.', 'Magazine;Washington;Opinion', 'Technology;Travel;Education;NewYorkandRegion', 'Style;Magazine;Books', 'Movies;Business;Washington', 'Technology;Travel', 'Arts;DiningandWine;Washington', 'Science;Arts;Health;Books', 'Magazine;Washington', 'Science;Magazine', 'Technology;FrontPage;Health;U.S.;Washington', 'FrontPage;Business', 'FrontPage;Arts;Obituaries', 'Movies;Style;Theater', 'Technology;Health', 'FrontPage;Health;NewYorkandRegion', 'Technology;Education;U.S.', 'Movies;Style;Magazine', 'Magazine;Washington;Books', 'Movies;Washington;NewYorkandRegion', 'Health;NewYorkandRegion', 'Technology;Automobiles', 'FrontPage;Health;Sports', 'Travel;RealEstate', 'Science;Movies;Education;Opinion', 'FrontPage;Education;Health;U.S.', 'Movies;Arts;DiningandWine', 'Travel;Magazine', 'Theater;WeekinReview', 'World;Obituaries;Books', "Corrections;Editors'Notes;Business", 'Technology;Arts;Style;Magazine', 'Arts;Style;Magazine;Books', 'Books;NewYorkandRegion', 'Education;U.S.;Obituaries', 'ThePublicEditor;Opinion', 'Technology;FrontPage;U.S.', 'Science;Opinion', 'Movies;Travel;Arts', 'Technology;Science;WeekinReview', 'World;FrontPage;Health;Wa ...
# 524

# %%
from collections import Counter
Counter(tagsC).most_common(50)
plotFreqDistAsBarChart(Counter(tagsC),20)

# %%
# Out:
# '/opt/nltk_data/nyt/data/1987'

# %%
import tarfile,os
import sys
import gzip
from contextlib import closing
from xml.etree import ElementTree as etree

tagsC = []

for i in range(6):
    with tarfile.open('/opt/nltk_data/nyt/data/2007/0'+str(i+1)+'.tgz') as archive:
        for member in archive:
            if member.isreg() and member.name.endswith('.xml'): # regular xml file
                with closing(archive.extractfile(member)) as xmlfile:
                    root = etree.parse(xmlfile).getroot()
                    for meta in root.findall(".//*[@name='online_sections']"):
                        newTags = meta.get("content").replace(" ","")
                        
                        tags = []
                        for tag in newTags.split(";"):
                            # Whitelist
                            if tag in ["Arts", "Business", "Science", "Sports", "Technology", "Health", "Opinion", "Style"]:
                                tags.append(tag)
                                continue
                            # Map tags
                            if tag in ["Books","Theater","Movies"]:
                                tags.append("Arts")
                                continue
                            if tag in ["Automobile"]:
                                tags.append("Business")
                                continue
                            if tag in ["Washington"]:
                                tags.append("Politics")
                                continue
                            if tag in ["ThePublicEditor","Editors'Notes"]:
                                tags.append("Opinion")
                                continue
                            
                            
                        # Remove Double Tags
                        tags = list(set(tags))
                
                        # Remove Empty Tags
                        if len(tags) == 0 :
                            continue
                        for tag in tags : 
                            tagsC.extend([tag])
                        
#print(tagsC)
# Out:
# 25648

# %%
print(len(tagsC))
plotFreqDistAsBarChart(Counter(tagsC),20)

# %%
from collections import Counter
c = Counter(tagsC)
print("Arts", str(c["Arts"]))
print("Opinion", str(c["Opinion"]))
print("Sports", str(c["Sports"]))
print("Business", str(c["Business"]))
print("Politics", str(c["Politics"]))
print("Style", str(c["Style"]))
print("Technology", str(c["Technology"]))
print("Health", str(c["Health"]))
print("Science", str(c["Science"]))
c.most_common(50)
plotFreqDistAsBarChart(c,20)
# Out:
# Arts 6757
# Opinion 3850
# Sports 3216
# Business 4164
# Politics 2005
# Style 1852
# Technology 1679
# Health 1630
# Science 495

# %%
import tarfile,os
import sys
import gzip
from contextlib import closing
from xml.etree import ElementTree as etree

tagsC = []

for i in range(6):
    with tarfile.open('/opt/nltk_data/nyt/data/2007/0'+str(i+1)+'.tgz') as archive:
        for member in archive:
            if member.isreg() and member.name.endswith('.xml'): # regular xml file
                with closing(archive.extractfile(member)) as xmlfile:
                    root = etree.parse(xmlfile).getroot()
                    for meta in root.findall(".//*[@name='online_sections']"):
                        newTags = meta.get("content").replace(" ","")
                        
                        tags = []
                        for tag in newTags.split(";"):
                            # Whitelist
                            if tag in ["Arts", "Business", "Science", "Sports", "Technology", "Health", "Opinion", "Style"]:
                                tags.append(tag)
                                continue
                            # Map tags
                            if tag in ["Books","Theater","Movies"]:
                                tags.append("Arts")
                                continue
                            if tag in ["Automobile"]:
                                tags.append("Business")
                                continue
                            if tag in ["Washington"]:
                                tags.append("Politics")
                                continue
                            if tag in ["ThePublicEditor","Editors'Notes"]:
                                tags.append("Opinion")
                                continue
                            
                            
                        # Remove Double Tags
                        tags = list(set(tags))
                
                        # Remove Empty Tags
', 'Opinion', 'Arts', 'Politics', 'Style', 'Business', 'Opinion', 'Arts', 'Sports', 'Arts', 'Style', 'Style', 'Arts', 'Opinion', 'Sports', 'Health', 'Sports', 'Arts', 'Arts', 'Arts', 'Opinion', 'Arts', 'Business', 'Arts', 'Arts', 'Politics', 'Arts', 'Technology', 'Sports', 'Health', 'Opinion', 'Arts', 'Arts', 'Arts', 'Business', 'Business', 'Arts', 'Business', 'Arts', 'Arts', 'Opinion', 'Sports', 'Arts', 'Business', 'Sports', 'Health', 'Arts', 'Opinion', 'Arts', 'Arts', 'Arts', 'Arts', 'Politics', 'Sports', 'Sports', 'Opinion', 'Arts', 'Opinion', 'Arts', 'Politics', 'Technology', 'Business', 'Arts', 'Sports', 'Politics', 'Sports', 'Arts', 'Politics', 'Opinion', 'Business', 'Arts', 'Arts', 'Opinion', 'Arts', 'Politics', 'Opinion', 'Opinion', 'Politics', 'Politics', 'Politics', 'Sports', 'Business', 'Arts', 'Politics', 'Arts', 'Arts', 'Arts', 'Business', 'Arts', 'Health', 'Arts', 'Sports', 'Politics', 'Politics', 'Opinion', 'Opinion', 'Sports', 'Arts', 'Opinion', 'Arts', 'Arts', 'Health', 'Arts', 'Arts', 'Sports', 'Sports', 'Sports', 'Arts', 'Sports', 'Politics', 'Arts', 'Arts', 'Business', 'Arts', 'Business', 'Arts', 'Sports', 'Sports', 'Sports', 'Arts', 'Arts', 'Sports', 'Business', 'Arts', 'Arts', 'Politics', 'Opinion', 'Sports', 'Politics', 'Arts', 'Opinion', 'Sports', 'Arts', 'Opinion', 'Arts', 'Politics', 'Arts', 'Arts', 'Arts', 'Business', 'Sports', 'Business', 'Health', 'Opinion', 'Arts', 'Arts', 'Arts ...
# 19305

# %%
print(len(tagsC))

# %%
from collections import Counter
Counter(tagsC).most_common(50)
# Out:
# [('Arts', 5865),
#  ('Opinion', 3142),
#  ('Sports', 3086),
#  ('Business', 2718),
#  ('Politics', 1698),
#  ('Style', 1578),
#  ('Health', 835),
#  ('Technology', 335),
#  ('Science', 48)]

# %%
for i in range(6):
    with tarfile.open('/opt/nltk_data/nyt/data/2007/0'+str(i+1)+'.tgz') as archive:
        for member in archive:
            if member.isreg() and member.name.endswith('.xml'): # regular xml file
                with closing(archive.extractfile(member)) as xmlfile:
                    root = etree.parse(xmlfile).getroot()
                    for meta in root.findall(".//*[@name='online_sections']"):
                        newTags = meta.get("content").replace(" ","")
                        
                        tags = []
                        for tag in newTags.split(";"):
                            # Whitelist
                            if tag in ["Arts", "Business", "Science", "Sports", "Technology", "Health", "Opinion", "Style"]:
                                tags.append(tag)
                                continue
                            # Map tags
                            if tag in ["Books","Theater","Movies"]:
                                tags.append("Arts")
                                continue
                            if tag in ["Automobile"]:
                                tags.append("Business")
                                continue
                            if tag in ["Washington"]:
                                tags.append("Politics")
                                continue
                            if tag in ["ThePublicEditor","Editors'Notes"]:
                                tags.append("Opinion")
                                continue
                            
                            
                        # Remove Double Tags
                        tags = list(set(tags))
                
                        # Remove Empty Tags
                        if len(tags) == 0 or len(tags) > 1 :
                            continue
                        tagsC.extend([';'.join(tags)])
                        
print(tagsC)
print(len(tagsC))
